# %%
# !pip install kagglehub

# %%
# !pwd
# Out:
# /teamspace/studios/this_studio/workshopIA/workshop_2/P2

# %%
import os
import kagglehub

# download latest version
path = kagglehub.dataset_download("jangedoo/utkface-new")

print("path to dataset files:", path)
# Out:
# path to dataset files: /teamspace/studios/this_studio/.cache/kagglehub/datasets/jangedoo/utkface-new/versions/1

# %%
base_path = "/teamspace/studios/this_studio/.cache/kagglehub/datasets/jangedoo/utkface-new/versions/1"

for folder in ["utkface_aligned_cropped", "crop_part1", "UTKFace"]:
    folder_path = os.path.join(base_path, folder)
    # filter for actual image files to get an accurate count and sample
    images = [f for f in os.listdir(folder_path) if f.lower().endswith((".jpg", ".jpeg", ".png"))]
    print(f"{folder}: {len(images)} images")
    print("sample:", images[:5])
    print("-" * 40)
# Out:
# utkface_aligned_cropped: 0 images
# sample: []
# ----------------------------------------
# crop_part1: 9780 images
# sample: ['1_0_0_20170110213018391.jpg.chip.jpg', '22_1_2_20170104021344006.jpg.chip.jpg', '9_0_0_20170110225508509.jpg.chip.jpg', '50_0_0_20170111203910911.jpg.chip.jpg', '1_1_0_20170110212607474.jpg.chip.jpg']
# ----------------------------------------
# UTKFace: 23708 images
# sample: ['77_1_0_20170113002117891.jpg.chip.jpg', '1_0_0_20170110213018391.jpg.chip.jpg', '55_0_3_20170119155052371.jpg.chip.jpg', '26_0_0_20170117195426941.jpg.chip.jpg', '22_1_2_20170104021344006.jpg.chip.jpg']
# ----------------------------------------
