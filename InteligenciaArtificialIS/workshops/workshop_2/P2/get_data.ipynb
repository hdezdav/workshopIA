# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: protobuf in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (4.23.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->kagglehub) (2026.1.4)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.16-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]/2 [kagglehub]
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.16

# %%
# !pwd
# Out:
# /teamspace/studios/this_studio/AIClass/InteligenciaArtificialIS/workshops/Workshop_2b/P2

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jangedoo/utkface-new")

print("Path to dataset files:", path)
# Out:
# Downloading to /teamspace/studios/this_studio/.cache/kagglehub/datasets/jangedoo/utkface-new/1.archive...
# 100%|██████████| 331M/331M [00:01<00:00, 245MB/s]
# Extracting files...
# Path to dataset files: /teamspace/studios/this_studio/.cache/kagglehub/datasets/jangedoo/utkface-new/versions/1

# %%
print(os.listdir(path))
# Out:
# ['utkface_aligned_cropped', 'crop_part1', 'UTKFace']

# %%
base_path = "/teamspace/studios/this_studio/.cache/kagglehub/datasets/jangedoo/utkface-new/versions/1"

for folder in ["utkface_aligned_cropped", "crop_part1", "UTKFace"]:
    folder_path = os.path.join(base_path, folder)
    images = [f for f in os.listdir(folder_path) if f.lower().endswith((".jpg", ".jpeg", ".png"))]
    print(f"{folder}: {len(images)} images")
    print("Sample:", images[:5])
    print("-" * 40)
# Out:
# utkface_aligned_cropped: 0 images
# Sample: []
# ----------------------------------------
# crop_part1: 9780 images
# Sample: ['29_0_2_20170104192909672.jpg.chip.jpg', '85_1_0_20170110183749939.jpg.chip.jpg', '96_1_2_20170105174624519.jpg.chip.jpg', '19_0_2_20170112003923755.jpg.chip.jpg', '1_1_2_20161219141502337.jpg.chip.jpg']
# ----------------------------------------
# UTKFace: 23708 images
# Sample: ['29_0_2_20170104192909672.jpg.chip.jpg', '85_1_0_20170110183749939.jpg.chip.jpg', '49_1_0_20170117160607343.jpg.chip.jpg', '54_0_3_20170119202510190.jpg.chip.jpg', '51_1_1_20170115235508848.jpg.chip.jpg']
# ----------------------------------------
